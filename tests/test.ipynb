# %%
from sentence_transformers import SentenceTransformer
import numpy as np
import os
PROJECT_ROOT = "/home/xuliren/repo/QA-Agent"
MODELS_DIR = os.path.join(PROJECT_ROOT, "models")
EMB_MODEL = os.path.join(MODELS_DIR, "m3e-base")
model = SentenceTransformer(EMB_MODEL)
model.save(os.path.join(MODELS_DIR, "m3e-base-st"))  # 保存为 SentenceTransformer 格式
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 import os
# ----> 4 PROJECT_ROOT = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
#       5 MODELS_DIR = os.path.join(PROJECT_ROOT, "models")
#       6 EMB_MODEL = os.path.join(MODELS_DIR, "m3e-base")
#
# NameError: name '__file__' is not defined
